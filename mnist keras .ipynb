# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Activation,Dropout,MaxPool2D,Flatten
import numpy as np 
from keras.utils import np_utils
from keras.datasets import mnist
np.random.seed(123)

# %%
(X_train,y_train),(X_test,y_test)= mnist.load_data()
X_train=X_train.reshape(X_train.shape[0],1,28,28)
X_test=X_test.reshape(X_test.shape[0],1,28,28) 
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
X_train=X_train/255.0
X_test=X_test/255.0

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(1,28,28),data_format="channels_first"))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# 8. Compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 9. Fit model on training data
model.fit(X_train, y_train,
          batch_size=32, nb_epoch=5, verbose=1)

# 10. Evaluate model on test data
score = model.evaluate(X_test, y_test, verbose=0)
print str(score)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 24s - loss: 0.2557 - acc: 0.9220
# Epoch 2/5
# 60000/60000 [==============================] - 24s - loss: 0.1023 - acc: 0.9705
# Epoch 3/5
# 60000/60000 [==============================] - 24s - loss: 0.0780 - acc: 0.9769
# Epoch 4/5
# 60000/60000 [==============================] - 24s - loss: 0.0649 - acc: 0.9799
# Epoch 5/5
# 60000/60000 [==============================] - 23s - loss: 0.0531 - acc: 0.9842
# [0.031311480209695222, 0.9889]

# %%
score
# Out:
# [0.031311480209695222, 0.9889]
